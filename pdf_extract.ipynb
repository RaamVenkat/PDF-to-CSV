# %%
import PyPDF2 as pdf
import re
import json
from pydantic import BaseModel
import pandas as pd

# %%
addr_reg = re.compile(r'Addr')
header_reg = re.compile(r'TOTAL')
arr = []
dic = {}
header = {"h1": "LLT179", 
          "h2": "CARBANERVE 300 MG", 
          "h3": "10"}

# %%
def insert(dic, k, cus, sta, header = None):
    dic['customer'] = cus
    dic['h1'] = header['h1']
    dic['h2'] = header['h2']
    dic['h3'] = header['h3']
    dic['station'] = sta
    dic['bill_no'] = k[-9]
    dic['date'] = k[-8]
    dic['batch'] = k[-7]
    dic['MRP'] = k[-6]
    dic['exp_da'] = k[-5]
    dic['qty'] = k[-4]
    dic['free_qty'] = k[-3]
    dic['sales_value']= k[-2]
    arr.append(dic)

# %%
def header_insert(header, k):
    header['h1']= k[0]
    header['h2']= k[1]
    header['h3']= k[2]

# %%
def pdf_reader(page_text):
    global dic 
    global header
    for i, line in enumerate(page_text):
        if header_reg.match(line):
            k= page_text[i+2].split('   ')
            str_list = list(filter(None, k))
            if "GRAND" not in page_text[i+2] and "Page" not in page_text[i+2]:
                # print(str_list)
                header_insert(header, str_list)
        
        if addr_reg.match(line):
            k= re.sub(' +', ' ', page_text[i-1]).split(' ')
            dic= {}
            insert(dic, k, ' '.join(k[:-10]), k[-10], header)
            
            def next_pages(j):
                cur = re.sub(' +', ' ', page_text[j]).split(' ')
                if len(cur)> 8:
                    global dic
                    cus = dic['customer']
                    sta = dic['station']
                    global header
                    dic = {}
                    insert(dic, cur, cus, sta, header)
                    if '--' not in page_text[j+1]:
                        next_pages(j+1)

            next_pages(i)

# %%
if __name__ == "__main__":
    pdf_file = open("D:\Emman\Source\AGARWAL LIFECARE.pdf","rb")
    pdf_read = pdf.PdfFileReader(pdf_file)
    
    # page_info = pdf_read.pages[0]
    # page_text = page_info.extractText().split('\n')
    # pdf_reader(page_text)
    # # Extracting every pages
    for i in range(0, pdf_read.getNumPages()):
        page_info = pdf_read.pages[i]
        page_text = page_info.extractText().split('\n')
        pdf_reader(page_text)
    pdf_file.close()

# %%
df= pd.DataFrame.from_dict(arr)
df.to_csv("D:\Emman\Source\AGARWAL LIFECARE.csv")

# %%
print(json.dumps(arr, indent=2))
# Out:
# [
#   {
#     "customer": "NIVIK PHARMACY",
#     "h1": "LLT179",
#     "h2": "CARBANERVE 300 MG",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC001978",
#     "date": "06/04/22",
#     "batch": "D2106045",
#     "MRP": "99.00",
#     "exp_da": "05/23",
#     "qty": "30",
#     "free_qty": "15",
#     "sales_value": "2121.60"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT179",
#     "h2": "CARBANERVE 300 MG",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC007337",
#     "date": "20/04/22",
#     "batch": "D2104022",
#     "MRP": "99.00",
#     "exp_da": "03/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "424.32"
#   },
#   {
#     "customer": "NIVIK PHARMACY",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC000200",
#     "date": "01/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "25",
#     "sales_value": "1423.80"
#   },
#   {
#     "customer": "NIVIK PHARMACY",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC000200",
#     "date": "01/04/22",
#     "batch": "EZF021003",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "40",
#     "free_qty": "0",
#     "sales_value": "5695.20"
#   },
#   {
#     "customer": "NIVIK PHARMACY",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC006484",
#     "date": "18/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "50",
#     "free_qty": "25",
#     "sales_value": "7119.00"
#   },
#   {
#     "customer": "NATURE MEDICARE,",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC000542",
#     "date": "02/04/22",
#     "batch": "EZF021003",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "NATURE MEDICARE,",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC006547",
#     "date": "18/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "SHREE RAM MEDICAL,",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC000746",
#     "date": "02/04/22",
#     "batch": "EZF021003",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "SHREE RAM MEDICAL,",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC007125",
#     "date": "19/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "854.28"
#   },
#   {
#     "customer": "SHREE RAM MEDICAL,",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC007962",
#     "date": "21/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "4",
#     "free_qty": "0",
#     "sales_value": "569.52"
#   },
#   {
#     "customer": "MEDICINE SHOP & GEN STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC000947",
#     "date": "04/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "MEDICINE SHOP & GEN STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC009106",
#     "date": "25/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "SONA MEDICALS",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC000978",
#     "date": "04/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "BALAJI MEDICALS . SAWAI",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "MADHOPUR",
#     "bill_no": "CC002010",
#     "date": "06/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "VRINDA MEDICARE...",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC002709",
#     "date": "07/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "2",
#     "sales_value": "1423.80"
#   },
#   {
#     "customer": "ANJALI MEDICAL & GEN.STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC003012",
#     "date": "08/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "KANCHAN MEDICAL AND GEN STO",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC003114",
#     "date": "08/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "SETHI MEDICALS",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC003135",
#     "date": "08/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "711.90"
#   },
#   {
#     "customer": "SETHI MEDICALS",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC009801",
#     "date": "26/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "CHANDRIKA MEDICAL STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC003482",
#     "date": "09/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "LOKESH MEDICAL & PROV.STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC003712",
#     "date": "11/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "NIKANT PHARMA",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC003720",
#     "date": "11/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "3",
#     "sales_value": "1423.80"
#   },
#   {
#     "customer": "NIKANT PHARMA",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC009288",
#     "date": "25/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "3",
#     "sales_value": "1423.80"
#   },
#   {
#     "customer": "PARSHWANATH MEDICAL & GEN S",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC003765",
#     "date": "11/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "142.38"
#   },
#   {
#     "customer": "KHANDELWAL MEDICAL STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "CHAKSU",
#     "bill_no": "CC004399",
#     "date": "12/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "SONIA MEDICAL & PRO. STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC004769",
#     "date": "13/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "HARI OM MED. & PR. STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC004849",
#     "date": "13/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "854.28"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC005091",
#     "date": "14/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "711.90"
#   },
#   {
#     "customer": "TARA MEDICOSE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC005177",
#     "date": "14/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "ISHWAR MEDICAL & GEN. STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC005615",
#     "date": "15/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "142.38"
#   },
#   {
#     "customer": "TAMBI MEDICOSE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC005918",
#     "date": "15/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "142.38"
#   },
#   {
#     "customer": "ANAND MEDICAL & GEN STORE .",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC006336",
#     "date": "16/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "SETHI MEDICAL/TRIVENI",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC006554",
#     "date": "18/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "NITIN MEDICAL & GEN STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC006787",
#     "date": "18/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "4",
#     "free_qty": "0",
#     "sales_value": "569.52"
#   },
#   {
#     "customer": "NITIN MEDICAL & GEN STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC011402",
#     "date": "30/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1423.80"
#   },
#   {
#     "customer": "VIJAY MEDICALS",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC007189",
#     "date": "19/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "JAIPUR MEDILINE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC007411",
#     "date": "20/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "3",
#     "sales_value": "1423.80"
#   },
#   {
#     "customer": "SARA MEDICALS",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC007559",
#     "date": "20/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "2847.60"
#   },
#   {
#     "customer": "SARA MEDICALS",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC008965",
#     "date": "23/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "2847.60"
#   },
#   {
#     "customer": "NEW A.K.RANDER MEDICAL STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "MAKRANA",
#     "bill_no": "CC007883",
#     "date": "21/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "142.38"
#   },
#   {
#     "customer": "VISHAL MEDICAL & PRO STORE*",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC007958",
#     "date": "21/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "KOMAL MEDICAL & GEN.STO.",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC008375",
#     "date": "22/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "142.38"
#   },
#   {
#     "customer": "HEERA MEDICAL STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC008440",
#     "date": "22/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "HEERA MEDICAL STORE",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC011268",
#     "date": "29/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "854.28"
#   },
#   {
#     "customer": "J.K MEDICAL STORE*",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "BHARATPUR",
#     "bill_no": "CC009101",
#     "date": "25/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "284.76"
#   },
#   {
#     "customer": "APOLLO PHARMACIES LIMITED...",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC010420",
#     "date": "27/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "711.90"
#   },
#   {
#     "customer": "SHREE SHYAM MEDICAL AGENCIES",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC010483",
#     "date": "27/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "2",
#     "sales_value": "1423.80"
#   },
#   {
#     "customer": "VINAYAK MEDICAL .",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC011430",
#     "date": "30/04/22",
#     "batch": "EZF021004",
#     "MRP": "210.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "427.14"
#   },
#   {
#     "customer": "VINAYAK MEDICAL .",
#     "h1": "LLT87",
#     "h2": "  CARNIGLO M TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "Addr:",
#     "date": "SHOP",
#     "batch": ".34",
#     "MRP": "ANAND",
#     "exp_da": "VIHAR",
#     "qty": "BAN",
#     "free_qty": "(22",
#     "sales_value": "GODOWN)"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT86",
#     "h2": "  GABAGESIC 100 MG TAB",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC006419",
#     "date": "18/04/22",
#     "batch": "D2108028",
#     "MRP": "63.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "135.00"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT98",
#     "h2": "  GABAGESIC 300 MG TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC006419",
#     "date": "18/04/22",
#     "batch": "D2105026",
#     "MRP": "144.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "310.71"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT98",
#     "h2": "  GABAGESIC 300 MG TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC009095",
#     "date": "25/04/22",
#     "batch": "D2105026",
#     "MRP": "144.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "207.14"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT98",
#     "h2": "  GABAGESIC 300 MG TAB",
#     "h3": "10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC009433",
#     "date": "25/04/22",
#     "batch": "D2105026",
#     "MRP": "144.00",
#     "exp_da": "04/23",
#     "qty": "9",
#     "free_qty": "0",
#     "sales_value": "932.13"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC000039",
#     "date": "01/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001413",
#     "date": "05/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007339",
#     "date": "20/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "SETHI MEDICAL/TRIVENI",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC000142",
#     "date": "01/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "NAGPAL MEDICAL & PROV.STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC000378",
#     "date": "01/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "857.15"
#   },
#   {
#     "customer": "NAGPAL MEDICAL & PROV.STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC004670",
#     "date": "13/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "SHRI RAM MEDICAL &PRO. STO",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC000605",
#     "date": "02/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "DR.K.G.MEDI SHOP",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001026",
#     "date": "04/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "DINESH MEDICAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001031",
#     "date": "04/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1714.30"
#   },
#   {
#     "customer": "DINESH MEDICAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003201",
#     "date": "09/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "1028.58"
#   },
#   {
#     "customer": "DINESH MEDICAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC005163",
#     "date": "14/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "1028.58"
#   },
#   {
#     "customer": "DINESH MEDICAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007760",
#     "date": "21/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1714.30"
#   },
#   {
#     "customer": "DINESH MEDICAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC008692",
#     "date": "23/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "1028.58"
#   },
#   {
#     "customer": "DINESH MEDICAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010057",
#     "date": "26/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1714.30"
#   },
#   {
#     "customer": "SETHI MEDICALS",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001034",
#     "date": "04/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "JAI SHRI MEDICAL & DEP.STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001261",
#     "date": "04/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "THAKURIA MEDICALS",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001300",
#     "date": "04/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "CHETNA MEDICAL & GEN STORE*",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001373",
#     "date": "04/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "CHETNA MEDICAL & GEN STORE*",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001791",
#     "date": "05/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "BHARAT MEDICAL STORES",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001633",
#     "date": "05/04/22",
#     "batch": "PEXAX54",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "NIPUN MEDICAL STORE (S)",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC002968",
#     "date": "08/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "25",
#     "free_qty": "5",
#     "sales_value": "4285.75"
#   },
#   {
#     "customer": "M2 PHARMACY,,",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC002961",
#     "date": "08/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "KAROL MEDICAL & PRO.STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC002990",
#     "date": "08/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "KAROL MEDICAL & PRO.STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC005237",
#     "date": "14/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "SHRI BALAJI MEDICAL & GEN STOR",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003025",
#     "date": "08/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "HEERA MEDICALS",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003042",
#     "date": "08/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "NEW MEDICINE POINT& GEN STOR",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003256",
#     "date": "09/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "NATIONAL MEDICOSE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003347",
#     "date": "09/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "NATIONAL MEDICOSE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010696",
#     "date": "28/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "VISHAL MEDICAL & PRO STORE*",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003369",
#     "date": "09/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "VISHAL MEDICAL & PRO STORE*",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010734",
#     "date": "28/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "PREM MEDICAL & GEN.STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003415",
#     "date": "09/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "GARIMA PHARMACY",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003525",
#     "date": "09/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "SHREE SHYAM MEDICAL AGENCIES",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003604",
#     "date": "09/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "25",
#     "free_qty": "5",
#     "sales_value": "4285.75"
#   },
#   {
#     "customer": "SHREE SHYAM MEDICAL AGENCIES",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC005909",
#     "date": "15/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "3428.60"
#   },
#   {
#     "customer": "SHREE SHYAM MEDICAL AGENCIES",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC008098",
#     "date": "21/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "3428.60"
#   },
#   {
#     "customer": "SHREE SHYAM MEDICAL AGENCIES",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009621",
#     "date": "25/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "3428.60"
#   },
#   {
#     "customer": "SHREE SHYAM MEDICAL AGENCIES",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010483",
#     "date": "27/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "10",
#     "free_qty": "2",
#     "sales_value": "1714.30"
#   },
#   {
#     "customer": "SHREE SHYAM MEDICAL AGENCIES",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010900",
#     "date": "28/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "3428.60"
#   },
#   {
#     "customer": "SANJEEV MEDICAL & GEN STORE..",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003926",
#     "date": "11/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "ROYAL MEDICAL & GEN STORE .",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003946",
#     "date": "11/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "VERDHMAN MEDICAL STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC004017",
#     "date": "11/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "10",
#     "free_qty": "2",
#     "sales_value": "1714.30"
#   },
#   {
#     "customer": "SHARDA MEDICAL & PROV. STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC004371",
#     "date": "12/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "MAHALAXMI MOBI MEDICAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC004513",
#     "date": "12/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "SONA MEDICALS",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC005778",
#     "date": "15/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "SONA MEDICALS",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC008942",
#     "date": "23/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "JAGDAMBA MEDICAL & GENERAL",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC006127",
#     "date": "16/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "HINDUSTAN MEDICOSE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007175",
#     "date": "19/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "JHALANI MEDICAL STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007314",
#     "date": "19/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "SHRI SHYAM MEDICAL & GEN.STO",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007376",
#     "date": "20/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "GOYAL MEDICAL STORE*",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007502",
#     "date": "20/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "CARING LIFE PHARMACY",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007637",
#     "date": "20/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "SHRI VINAYAK MEDICAL STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC007866",
#     "date": "21/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "S.J PHARMACY",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC008146",
#     "date": "22/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "MEDICOWIN PHARMACY",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC008391",
#     "date": "22/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "SHIV.MEDICAL & GENERAL STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC008599",
#     "date": "23/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "GOVIND MEDICAL STORE .",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC008990",
#     "date": "23/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "GOVIND MEDICAL STORE .",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009186",
#     "date": "25/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "514.29"
#   },
#   {
#     "customer": "MADHURIKA MEDICAL & GEN. STO",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009022",
#     "date": "23/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "MADHURIKA MEDICAL & GEN. STO",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010864",
#     "date": "28/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "SHRI VINAYAK MED & PRO STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009057",
#     "date": "23/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "A.K.RANDER MEDICOSE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "NAGAUR",
#     "bill_no": "CC009238",
#     "date": "25/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "SHRI BALAJI MED & GEN STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009254",
#     "date": "25/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "VIHAN MEDICAL & GEN STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009335",
#     "date": "25/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "ANKIT MEDICOSE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009765",
#     "date": "26/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "342.86"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009960",
#     "date": "26/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "857.15"
#   },
#   {
#     "customer": "WE LOVE CARING LLP",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010119",
#     "date": "27/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "SHRI BALAJI MEDICALS .",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010301",
#     "date": "27/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "MEDKIT PHARMACY(ARS NEXA SQ",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010328",
#     "date": "27/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "ADITYA PHARMA*",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010650",
#     "date": "28/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "DEEP MEDICAL & GEN STORE",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010755",
#     "date": "28/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "RIDHI SIDHI MEDICAL & PRO STOR",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC010764",
#     "date": "28/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "AGRAWAL MEDICOS",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC011181",
#     "date": "29/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "SHIV MEDICAL & GEN.STORE,,",
#     "h1": "LLT26",
#     "h2": "  GABAGESIC GEL",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC011203",
#     "date": "29/04/22",
#     "batch": "PEXAX55",
#     "MRP": "240.00",
#     "exp_da": "07/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "171.43"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT79",
#     "h2": "  GABAGESIC NT 100 MG",
#     "h3": " 10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC001165",
#     "date": "04/04/22",
#     "batch": "PEXBE14",
#     "MRP": "88.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "188.55"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT79",
#     "h2": "  GABAGESIC NT 100 MG",
#     "h3": " 10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC006992",
#     "date": "19/04/22",
#     "batch": "PEXBE16",
#     "MRP": "88.00",
#     "exp_da": "09/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "314.25"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT79",
#     "h2": "  GABAGESIC NT 100 MG",
#     "h3": " 10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC008641",
#     "date": "23/04/22",
#     "batch": "PEXBE16",
#     "MRP": "88.00",
#     "exp_da": "09/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "314.25"
#   },
#   {
#     "customer": "SHRI MAHAVIR MEDICAL STORE.",
#     "h1": "LLT80",
#     "h2": "  GABAGESIC NT 400 MG",
#     "h3": " 10 TAB",
#     "station": "SIKAR",
#     "bill_no": "CC007838",
#     "date": "21/04/22",
#     "batch": "PEXBF17",
#     "MRP": "217.00",
#     "exp_da": "05/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "310.00"
#   },
#   {
#     "customer": "SHREE SALASAR MEDICAL STORE",
#     "h1": "LLT80",
#     "h2": "  GABAGESIC NT 400 MG",
#     "h3": " 10 TAB",
#     "station": "HANUMANGADH",
#     "bill_no": "CC007980",
#     "date": "21/04/22",
#     "batch": "PEXBF20",
#     "MRP": "217.00",
#     "exp_da": "11/23",
#     "qty": "300",
#     "free_qty": "0",
#     "sales_value": "46500.00"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT80",
#     "h2": "  GABAGESIC NT 400 MG",
#     "h3": " 10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC008377",
#     "date": "22/04/22",
#     "batch": "PEXBF17",
#     "MRP": "217.00",
#     "exp_da": "05/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "465.00"
#   },
#   {
#     "customer": "DUNESH MEDICAL HALL",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC001694",
#     "date": "05/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "435.00"
#   },
#   {
#     "customer": "SARA MEDICALS",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003069",
#     "date": "08/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "2900.00"
#   },
#   {
#     "customer": "SARA MEDICALS",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003474",
#     "date": "09/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "2",
#     "sales_value": "1450.00"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC003638",
#     "date": "11/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "435.00"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC004188",
#     "date": "12/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1450.00"
#   },
#   {
#     "customer": "RAMA MEDICALS",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC005256",
#     "date": "14/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "290.00"
#   },
#   {
#     "customer": "RAMA MEDICALS",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009826",
#     "date": "26/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "290.00"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC009095",
#     "date": "25/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1450.00"
#   },
#   {
#     "customer": "VRINDA MEDICARE...",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC011373",
#     "date": "30/04/22",
#     "batch": "R2131108K",
#     "MRP": "203.00",
#     "exp_da": "04/23",
#     "qty": "20",
#     "free_qty": "16",
#     "sales_value": "2900.00"
#   },
#   {
#     "customer": "VRINDA MEDICARE...",
#     "h1": "LLT23",
#     "h2": "  IDEBEST 45 MG",
#     "h3": " 10",
#     "station": "JAIPUR",
#     "bill_no": "CC011373",
#     "date": "30/04/22",
#     "batch": "R2231101A",
#     "MRP": "203.00",
#     "exp_da": "06/23",
#     "qty": "60",
#     "free_qty": "0",
#     "sales_value": "8700.00"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT170",
#     "h2": " LIVIZ TAB",
#     "h3": "  10",
#     "station": "JAIPUR",
#     "bill_no": "CC000439",
#     "date": "01/04/22",
#     "batch": "LLTI2004",
#     "MRP": "210.00",
#     "exp_da": "08/22",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "450.00"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT170",
#     "h2": " LIVIZ TAB",
#     "h3": "  10",
#     "station": "JAIPUR",
#     "bill_no": "CC005017",
#     "date": "13/04/22",
#     "batch": "LLTI2004",
#     "MRP": "210.00",
#     "exp_da": "08/22",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "450.00"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT170",
#     "h2": " LIVIZ TAB",
#     "h3": "  10",
#     "station": "JAIPUR",
#     "bill_no": "CC005876",
#     "date": "15/04/22",
#     "batch": "LLTI2004",
#     "MRP": "210.00",
#     "exp_da": "08/22",
#     "qty": "4",
#     "free_qty": "0",
#     "sales_value": "600.00"
#   },
#   {
#     "customer": "GOYAL MEDICAL & GEN STORE",
#     "h1": "LLT170",
#     "h2": " LIVIZ TAB",
#     "h3": "  10",
#     "station": "JAIPUR",
#     "bill_no": "CC002513",
#     "date": "07/04/22",
#     "batch": "LLTI2004",
#     "MRP": "210.00",
#     "exp_da": "08/22",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "300.00"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT170",
#     "h2": " LIVIZ TAB",
#     "h3": "  10",
#     "station": "JAIPUR",
#     "bill_no": "CC002785",
#     "date": "08/04/22",
#     "batch": "LLTI2004",
#     "MRP": "210.00",
#     "exp_da": "08/22",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "300.00"
#   },
#   {
#     "customer": "RAWAT MEDICAL & GENERAL STO",
#     "h1": "LLT170",
#     "h2": " LIVIZ TAB",
#     "h3": "  10",
#     "station": "JAIPUR",
#     "bill_no": "CC001581",
#     "date": "05/04/22",
#     "batch": "D2105014",
#     "MRP": "180.00",
#     "exp_da": "04/23",
#     "qty": "12",
#     "free_qty": "0",
#     "sales_value": "1542.84"
#   },
#   {
#     "customer": "MANOJ MEDICAL STORE .",
#     "h1": "LLT34",
#     "h2": "  OLINSTAB F TAB",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC002058",
#     "date": "06/04/22",
#     "batch": "D2109018",
#     "MRP": "93.50",
#     "exp_da": "08/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "400.74"
#   },
#   {
#     "customer": "MANOJ MEDICAL STORE .",
#     "h1": "LLT34",
#     "h2": "  OLINSTAB F TAB",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC002540",
#     "date": "07/04/22",
#     "batch": "D2109018",
#     "MRP": "93.50",
#     "exp_da": "08/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "667.90"
#   },
#   {
#     "customer": "MANOJ MEDICAL STORE .",
#     "h1": "LLT34",
#     "h2": "  OLINSTAB F TAB",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC007069",
#     "date": "19/04/22",
#     "batch": "D2111030",
#     "MRP": "93.50",
#     "exp_da": "10/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "667.90"
#   },
#   {
#     "customer": "HARI OM MED. & PR. STORE",
#     "h1": "LLT34",
#     "h2": "  OLINSTAB F TAB",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC004852",
#     "date": "13/04/22",
#     "batch": "D2111030",
#     "MRP": "93.50",
#     "exp_da": "10/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "400.74"
#   },
#   {
#     "customer": "AKSHARDHAM MEDICAL",
#     "h1": "LLT01",
#     "h2": "  OXVUN 50 MG",
#     "h3": "10 TAB",
#     "station": "DOUSA",
#     "bill_no": "CC003933",
#     "date": "11/04/22",
#     "batch": "D2108027",
#     "MRP": "150.00",
#     "exp_da": "07/23",
#     "qty": "20",
#     "free_qty": "4",
#     "sales_value": "2142.80"
#   },
#   {
#     "customer": "ANKUSH MEDICAL STORE",
#     "h1": "LLT31",
#     "h2": "  PATINEX  25 TAB",
#     "h3": "  1 *10",
#     "station": "JAIPUR",
#     "bill_no": "CC001961",
#     "date": "06/04/22",
#     "batch": "D2106028",
#     "MRP": "170.00",
#     "exp_da": "05/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1214.30"
#   },
#   {
#     "customer": "TANU MEDICALS",
#     "h1": "LLT31",
#     "h2": "  PATINEX  25 TAB",
#     "h3": "  1 *10",
#     "station": "JAIPUR",
#     "bill_no": "CC001976",
#     "date": "06/04/22",
#     "batch": "D2101018",
#     "MRP": "165.00",
#     "exp_da": "12/22",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "589.25"
#   },
#   {
#     "customer": "AMAR KAUSTUBH MEDICALS",
#     "h1": "LLT31",
#     "h2": "  PATINEX  25 TAB",
#     "h3": "  1 *10",
#     "station": "JAIPUR",
#     "bill_no": "CC004807",
#     "date": "13/04/22",
#     "batch": "D2101018",
#     "MRP": "165.00",
#     "exp_da": "12/22",
#     "qty": "3",
#     "free_qty": "0",
#     "sales_value": "353.55"
#   },
#   {
#     "customer": "AMAR KAUSTUBH MEDICALS",
#     "h1": "LLT31",
#     "h2": "  PATINEX  25 TAB",
#     "h3": "  1 *10",
#     "station": "JAIPUR",
#     "bill_no": "CC004807",
#     "date": "13/04/22",
#     "batch": "D2012004",
#     "MRP": "165.00",
#     "exp_da": "11/22",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "235.70"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE.",
#     "h1": "LLT31",
#     "h2": "  PATINEX  25 TAB",
#     "h3": "  1 *10",
#     "station": "JAIPUR",
#     "bill_no": "CC007025",
#     "date": "19/04/22",
#     "batch": "D2111031",
#     "MRP": "170.00",
#     "exp_da": "10/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1214.30"
#   },
#   {
#     "customer": "AKSHARDHAM MEDICAL",
#     "h1": "LLT31",
#     "h2": "  PATINEX  25 TAB",
#     "h3": "  1 *10",
#     "station": "DOUSA",
#     "bill_no": "CC003933",
#     "date": "11/04/22",
#     "batch": "D2108009.",
#     "MRP": "143.00",
#     "exp_da": "07/23",
#     "qty": "10",
#     "free_qty": "2",
#     "sales_value": "1021.40"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT20",
#     "h2": "  PRONATE EZ TAB",
#     "h3": "0",
#     "station": "JAIPUR",
#     "bill_no": "CC001846",
#     "date": "05/04/22",
#     "batch": "PEXAR21",
#     "MRP": "66.00",
#     "exp_da": "06/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "471.40"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT20",
#     "h2": "  PRONATE EZ TAB",
#     "h3": "0",
#     "station": "JAIPUR",
#     "bill_no": "CC003502",
#     "date": "09/04/22",
#     "batch": "PEXAR21",
#     "MRP": "66.00",
#     "exp_da": "06/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "282.84"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT20",
#     "h2": "  PRONATE EZ TAB",
#     "h3": "0",
#     "station": "JAIPUR",
#     "bill_no": "CC005017",
#     "date": "13/04/22",
#     "batch": "PEXAR22",
#     "MRP": "66.00",
#     "exp_da": "08/23",
#     "qty": "7",
#     "free_qty": "0",
#     "sales_value": "329.98"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT20",
#     "h2": "  PRONATE EZ TAB",
#     "h3": "0",
#     "station": "JAIPUR",
#     "bill_no": "CC006754",
#     "date": "18/04/22",
#     "batch": "PEXAR21",
#     "MRP": "66.00",
#     "exp_da": "06/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "282.84"
#   },
#   {
#     "customer": "H.R. MEDICALS",
#     "h1": "LLT20",
#     "h2": "  PRONATE EZ TAB",
#     "h3": "0",
#     "station": "JAIPUR",
#     "bill_no": "CC008953",
#     "date": "23/04/22",
#     "batch": "PEXAR23",
#     "MRP": "66.00",
#     "exp_da": "11/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "282.84"
#   },
#   {
#     "customer": "MADANI MEDICAL STORE",
#     "h1": "LLT20",
#     "h2": "  PRONATE EZ TAB",
#     "h3": "0",
#     "station": "NAGAUR",
#     "bill_no": "CC005552",
#     "date": "15/04/22",
#     "batch": "PEXAR21",
#     "MRP": "66.00",
#     "exp_da": "06/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "94.28"
#   },
#   {
#     "customer": "SHIV MEDICAL & GENERAL STORE.",
#     "h1": "LL1T120",
#     "h2": "PRONATE F TAB",
#     "h3": " 10 TAB",
#     "station": "JAIPUR",
#     "bill_no": "CC010667",
#     "date": "28/04/22",
#     "batch": "PEXAB23",
#     "MRP": "107.50",
#     "exp_da": "10/23",
#     "qty": "20",
#     "free_qty": "0",
#     "sales_value": "1535.80"
#   },
#   {
#     "customer": "SHRI JI MEDICAL &PRO. STO",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC001353",
#     "date": "04/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "372.88"
#   },
#   {
#     "customer": "AAKANSHA MEDICAL",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC002196",
#     "date": "06/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "372.88"
#   },
#   {
#     "customer": "AAKANSHA MEDICAL",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC002635",
#     "date": "07/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "745.76"
#   },
#   {
#     "customer": "JAIN MEDICALS",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC005068",
#     "date": "13/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "372.88"
#   },
#   {
#     "customer": "VRINDA MEDICARE...",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC008063",
#     "date": "21/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "50",
#     "free_qty": "10",
#     "sales_value": "18644.00"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC009095",
#     "date": "25/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "372.88"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC009290",
#     "date": "25/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "372.88"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC009356",
#     "date": "25/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "1864.40"
#   },
#   {
#     "customer": "ARZT AND HEALTH P.VT.L.TD",
#     "h1": "LLT102",
#     "h2": " QLINO CAPS",
#     "h3": " 1*10 cap  ",
#     "station": "JAIPUR",
#     "bill_no": "CC009750",
#     "date": "26/04/22",
#     "batch": "X21K001",
#     "MRP": "550.00",
#     "exp_da": "10/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "1864.40"
#   },
#   {
#     "customer": "SUPRIM MEDICAL & PRO.STORE",
#     "h1": "LLT111",
#     "h2": " SERMIND 25 MG TAB",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC011150",
#     "date": "29/04/22",
#     "batch": "D2111007",
#     "MRP": "43.00",
#     "exp_da": "10/23",
#     "qty": "20",
#     "free_qty": "0",
#     "sales_value": "614.20"
#   },
#   {
#     "customer": "SUMAN MEDICAL & PRO.STORE",
#     "h1": "LLT10",
#     "h2": "  SERMIND 50 MG TAB",
#     "h3": "0",
#     "station": "JAIPUR",
#     "bill_no": "CC001051",
#     "date": "04/04/22",
#     "batch": "D2106055",
#     "MRP": "77.50",
#     "exp_da": "05/23",
#     "qty": "2",
#     "free_qty": "0",
#     "sales_value": "110.70"
#   },
#   {
#     "customer": "SALASAR MEDICOSE",
#     "h1": "LLT10",
#     "h2": "  SERMIND 50 MG TAB",
#     "h3": "0",
#     "station": "JAIPUR",
#     "bill_no": "CC006959",
#     "date": "19/04/22",
#     "batch": "D2106055",
#     "MRP": "77.50",
#     "exp_da": "05/23",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "332.10"
#   },
#   {
#     "customer": "JAIPUR PHARMCY",
#     "h1": "LLT62",
#     "h2": "  VENLITE CZ 50 MG TAB",
#     "h3": "10",
#     "station": "JAIPUR",
#     "bill_no": "CC006045",
#     "date": "16/04/22",
#     "batch": "ST-21043",
#     "MRP": "148.00",
#     "exp_da": "04/23",
#     "qty": "1",
#     "free_qty": "0",
#     "sales_value": "105.71"
#   },
#   {
#     "customer": "ANKUSH MEDICAL STORE",
#     "h1": "LLT13",
#     "h2": "  VENLITE OD 100 MG TAB",
#     "h3": "  0",
#     "station": "JAIPUR",
#     "bill_no": "CC001961",
#     "date": "06/04/22",
#     "batch": "R2022205G",
#     "MRP": "220.00",
#     "exp_da": "06/22",
#     "qty": "6",
#     "free_qty": "0",
#     "sales_value": "942.84"
#   },
#   {
#     "customer": "ANKUSH MEDICAL STORE",
#     "h1": "LLT13",
#     "h2": "  VENLITE OD 100 MG TAB",
#     "h3": "  0",
#     "station": "JAIPUR",
#     "bill_no": "CC006513",
#     "date": "18/04/22",
#     "batch": "D2110030",
#     "MRP": "240.00",
#     "exp_da": "09/23",
#     "qty": "10",
#     "free_qty": "0",
#     "sales_value": "1714.30"
#   },
#   {
#     "customer": "TANU MEDICALS",
#     "h1": "LLT13",
#     "h2": "  VENLITE OD 100 MG TAB",
#     "h3": "  0",
#     "station": "JAIPUR",
#     "bill_no": "CC001976",
#     "date": "06/04/22",
#     "batch": "R2022205G",
#     "MRP": "220.00",
#     "exp_da": "06/22",
#     "qty": "4",
#     "free_qty": "0",
#     "sales_value": "628.56"
#   },
#   {
#     "customer": "AMAR KAUSTUBH MEDICALS",
#     "h1": "LLT13",
#     "h2": "  VENLITE OD 100 MG TAB",
#     "h3": "  0",
#     "station": "JAIPUR",
#     "bill_no": "CC004807",
#     "date": "13/04/22",
#     "batch": "D2110030",
#     "MRP": "240.00",
#     "exp_da": "09/23",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "857.15"
#   },
#   {
#     "customer": "ANKUSH MEDICAL STORE",
#     "h1": "LLT13",
#     "h2": "  VENLITE OD 100 MG TAB",
#     "h3": "  0",
#     "station": "JAIPUR",
#     "bill_no": "CC009746",
#     "date": "26/04/22",
#     "batch": "R2013006H",
#     "MRP": "121.00",
#     "exp_da": "07/22",
#     "qty": "5",
#     "free_qty": "0",
#     "sales_value": "432.15"
#   }
# ]
